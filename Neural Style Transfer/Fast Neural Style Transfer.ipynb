# %%
import tensorflow as tf
import tensorflow_hub as hub
from matplotlib import pyplot as plt
import numpy as np
import cv2
# !pip install numpy==1.19.5

# %%
cd /content/drive/MyDrive/Coursework/DS 552/Project
# Out:
# /content/drive/MyDrive/Coursework/DS 552/Project

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %% [markdown]
# ## Applying Painting Style on Image

# %%
content_image = load_image('park.jpeg')
style_image = load_image('vangogh.jpeg')

plt.title("Content Image")
plt.imshow(np.squeeze(content_image))

# %%
plt.title("Style Image")
plt.imshow(np.squeeze(style_image))

# %%
## Stylizing image

stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.title("Stylized Image")
# Out:
# Text(0.5, 1.0, 'Stylized Image')

# %% [markdown]
# ## Applying Intricate Painting onto Image

# %%
content_image = load_image('dog.jpeg')
style_image = load_image('lastjudgment.jpg')

plt.title("Content Image")
plt.imshow(np.squeeze(content_image))

# %% [markdown]
# We choose a style image which contains a lot of intricacies in the painting to see how the style may be applied. This painting is the *Last Judgment* by Michelangelo.

# %%
plt.title("Style Image")
plt.imshow(np.squeeze(style_image))

# %% [markdown]
# We see that the resulting image has a very interesting texture which is more noticeable if we zoom in. The overall structure of the dog from the content image remains but at first look, appears to be similar to a grayscale image.

# %%
## Stylizing image

stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.title("Stylized Image")
# Out:
# Text(0.5, 1.0, 'Stylized Image')

# %% [markdown]
# ## Applying Image Style on Image

# %%
content_image = load_image('park.jpeg')
style_image = load_image('castle.JPG')

plt.title("Content Image")
plt.imshow(np.squeeze(content_image))

# %%
plt.title("Style Image")
plt.imshow(np.squeeze(style_image))

# %% [markdown]
# We see that the following image is not very clear as both the content and the style image have multiple types of different textures and colors.

# %%
## Stylizing image

stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.title("Stylized Image")
# Out:
# Text(0.5, 1.0, 'Stylized Image')
